# %%
import sys
import os

print("Python executable:", sys.executable)
print("Python version:", sys.version)
print("Current environment:", os.environ.get("CONDA_DEFAULT_ENV"))
# Out:
# Python executable: /home/roger/miniconda3/envs/ds/bin/python
# Python version: 3.11.15 (main, Jun 11 2026, 15:20:16) [GCC 14.3.0]
# Current environment: ds

# %%
import numpy as np
import pandas as pd

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
# Out:
# NumPy: 2.4.6
# Pandas: 3.0.3
